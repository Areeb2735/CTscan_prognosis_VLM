# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import pandas as pd
#
# ModuleNotFoundError: No module named 'pandas'

# %%
# compare the two txt file and find the common lines

def compare_txt(file1, file2):
    with open(file1) as f:
        lines1 = f.readlines()
    with open(file2) as f:
        lines2 = f.readlines()
    common_lines = []
    diff_lines = []
    for line in lines1:
        if line in lines2:
            common_lines.append(line)
        else:
            diff_lines.append(line)
    return diff_lines

compare_txt('filenames.txt', 'filenames_home.txt')
# Out:
# ['MDA-001_pt_roi.nii.gz\n',
#  'MDA-001_ct_roi.nii.gz\n',
#  'MDA-001_mask_roi.nii.gz\n',
#  'MDA-003_pt_roi.nii.gz\n',
#  'MDA-003_ct_roi.nii.gz\n',
#  'MDA-003_mask_roi.nii.gz\n',
#  'MDA-004_pt_roi.nii.gz\n',
#  'MDA-004_ct_roi.nii.gz\n',
#  'MDA-004_mask_roi.nii.gz\n',
#  'MDA-005_pt_roi.nii.gz\n',
#  'MDA-005_ct_roi.nii.gz\n',
#  'MDA-005_mask_roi.nii.gz\n',
#  'MDA-006_pt_roi.nii.gz\n',
#  'MDA-006_ct_roi.nii.gz\n',
#  'MDA-006_mask_roi.nii.gz\n',
#  'MDA-007_pt_roi.nii.gz\n',
#  'MDA-007_ct_roi.nii.gz\n',
#  'MDA-007_mask_roi.nii.gz\n',
#  'MDA-010_pt_roi.nii.gz\n',
#  'MDA-010_ct_roi.nii.gz\n',
#  'MDA-010_mask_roi.nii.gz\n',
#  'MDA-011_pt_roi.nii.gz\n',
#  'MDA-011_ct_roi.nii.gz\n',
#  'MDA-011_mask_roi.nii.gz\n',
#  'MDA-012_pt_roi.nii.gz\n',
#  'MDA-012_ct_roi.nii.gz\n',
#  'MDA-012_mask_roi.nii.gz\n',
#  'MDA-013_pt_roi.nii.gz\n',
#  'MDA-013_ct_roi.nii.gz\n',
#  'MDA-013_mask_roi.nii.gz\n',
#  'MDA-014_pt_roi.nii.gz\n',
#  'MDA-014_ct_roi.nii.gz\n',
#  'MDA-014_mask_roi.nii.gz\n',
#  'MDA-015_pt_roi.nii.gz\n',
#  'MDA-015_ct_roi.nii.gz\n',
#  'MDA-015_mask_roi.nii.gz\n',
#  'MDA-016_pt_roi.nii.gz\n',
#  'MDA-016_ct_roi.nii.gz\n',
#  'MDA-016_mask_roi.nii.gz\n',
#  'MDA-017_pt_roi.nii.gz\n',
#  'MDA-017_ct_roi.nii.gz\n',
#  'MDA-017_mask_roi.nii.gz\n',
#  'MDA-018_pt_roi.nii.gz\n',
#  'MDA-018_ct_roi.nii.gz\n',
#  'MDA-018_mask_roi.nii.gz\n',
#  'MDA-019_pt_roi.nii.gz\n',
#  'MDA-019_ct_roi.nii.gz\n',
#  'MDA-019_mask_roi.nii.gz\n',
#  'MDA-020_pt_roi.nii.gz\n',
#  'MDA-020_ct_roi.nii.gz\n',
#  'MDA-020_mask_roi.nii.gz\n',
#  'MDA-021_pt_roi.nii.gz\n',
#  'MDA-021_ct_roi.nii.gz\n',
#  'MDA-021_mask_roi.nii.gz\n',
#  'MDA-022_pt_roi.nii.gz\n',
#  'MDA-022_ct_roi.nii.gz\n',
#  'MDA-022_mask_roi.nii.gz\n',
#  'MDA-023_pt_roi.nii.gz\n',
#  'MDA-023_ct_roi.nii.gz\n',
#  'MDA-023_mask_roi.nii.gz\n',
#  'MDA-024_pt_roi.nii.gz\n',
#  'MDA-024_ct_roi.nii.gz\n',
#  'MDA-024_mask_roi.nii.gz\n',
#  'MDA-025_pt_roi.nii.gz\n',
#  'MDA-025_ct_roi.nii.gz\n',
#  'MDA-025_mask_roi.nii.gz\n',
#  'MDA-026_pt_roi.nii.gz\n',
#  'MDA-026_ct_roi.nii.gz\n',
#  'MDA-026_mask_roi.nii.gz\n',
#  'MDA-027_pt_roi.nii.gz\n',
#  'MDA-027_ct_roi.nii.gz\n',
#  'MDA-027_mask_roi.nii.gz\n',
#  'MDA-028_pt_roi.nii.gz\n',
#  'MDA-028_ct_roi.nii.gz\n',
#  'MDA-028_mask_roi.nii.gz\n',
#  'MDA-029_pt_roi.nii.gz\n',
#  'MDA-029_ct_roi.nii.gz\n',
#  'MDA-029_mask_roi.nii.gz\n',
#  'MDA-030_pt_roi.nii.gz\n',
#  'MDA-030_ct_roi.nii.gz\n',
#  'MDA-030_mask_roi.nii.gz\n',
#  'MDA-031_pt_roi.nii.gz\n',
#  'MDA-031_ct_roi.nii.gz\n',
#  'MDA-031_mask_roi.nii.gz\n',
#  'MDA-032_pt_roi.nii.gz\n',
#  'MDA-032_ct_roi.nii.gz\n',
#  'MDA-032_mask_roi.nii.gz\n',
#  'MDA-033_pt_roi.nii.gz\n',
#  'MDA-033_ct_roi.nii.gz\n',
#  'MDA-033_mask_roi.nii.gz\n',
#  'MDA-034_pt_roi.nii.gz\n',
#  'MDA-034_ct_roi.nii.gz\n',
#  'MDA-034_mask_roi.nii.gz\n',
#  'MDA-035_pt_roi.nii.gz\n',
#  'MDA-035_ct_roi.nii.gz\n',
#  'MDA-035_mask_roi.nii.gz\n',
#  'MDA-036_pt_roi.nii.gz\n',
#  'MDA-036_ct_roi.nii.gz\n',
#  'MDA-036_mask_roi.nii.gz\n',
#  'MDA-037_pt_roi.nii.gz\n',
#  'MDA-037_ct_roi.nii.gz\n',
#  'MDA-037_mask_roi.nii.gz\n',
#  'MDA-038_pt_roi.nii.gz\n',
#  'MDA-038_ct_roi.nii.gz\n',
#  'MDA-038_mask_roi.nii.gz\n',
#  'MDA-039_pt_roi.nii.gz\n',
#  'MDA-039_ct_roi.nii.gz\n',
#  'MDA-039_mask_roi.nii.gz\n',
#  'MDA-040_pt_roi.nii.gz\n',
#  'MDA-040_ct_roi.nii.gz\n',
#  'MDA-040_mask_roi.nii.gz\n',
#  'MDA-041_pt_roi.nii.gz\n',
#  'MDA-041_ct_roi.nii.gz\n',
#  'MDA-041_mask_roi.nii.gz\n',
#  'MDA-042_pt_roi.nii.gz\n',
#  'MDA-042_ct_roi.nii.gz\n',
#  'MDA-042_mask_roi.nii.gz\n',
#  'MDA-043_pt_roi.nii.gz\n',
#  'MDA-043_ct_roi.nii.gz\n',
#  'MDA-043_mask_roi.nii.gz\n',
#  'MDA-044_pt_roi.nii.gz\n',
#  'MDA-044_ct_roi.nii.gz\n',
#  'MDA-044_mask_roi.nii.gz\n',
#  'MDA-045_pt_roi.nii.gz\n',
#  'MDA-045_ct_roi.nii.gz\n',
#  'MDA-045_mask_roi.nii.gz\n',
#  'MDA-046_pt_roi.nii.gz\n',
#  'MDA-046_ct_roi.nii.gz\n',
#  'MDA-046_mask_roi.nii.gz\n',
#  'MDA-047_pt_roi.nii.gz\n',
#  'MDA-047_ct_roi.nii.gz\n',
#  'MDA-047_mask_roi.nii.gz\n',
#  'MDA-048_pt_roi.nii.gz\n',
#  'MDA-048_ct_roi.nii.gz\n',
#  'MDA-048_mask_roi.nii.gz\n',
#  'MDA-049_pt_roi.nii.gz\n',
#  'MDA-049_ct_roi.nii.gz\n',
#  'MDA-049_mask_roi.nii.gz\n',
#  'MDA-050_pt_roi.nii.gz\n',
#  'MDA-050_ct_roi.nii.gz\n',
#  'MDA-050_mask_roi.nii.gz\n',
#  'MDA-051_pt_roi.nii.gz\n',
#  'MDA-051_ct_roi.nii.gz\n',
#  'MDA-051_mask_roi.nii.gz\n',
#  'MDA-052_pt_roi.nii.gz\n',
#  'MDA-052_ct_roi.nii.gz\n',
#  'MDA-052_mask_roi.nii.gz\n',
#  'MDA-053_pt_roi.nii.gz\n',
#  'MDA-053_ct_roi.nii.gz\n',
#  'MDA-053_mask_roi.nii.gz\n',
#  'MDA-054_pt_roi.nii.gz\n',
#  'MDA-054_ct_roi.nii.gz\n',
#  'MDA-054_mask_roi.nii.gz\n',
#  'MDA-055_pt_roi.nii.gz\n',
#  'MDA-055_ct_roi.nii.gz\n',
#  'MDA-055_mask_roi.nii.gz\n',
#  'MDA-056_pt_roi.nii.gz\n',
#  'MDA-056_ct_roi.nii.gz\n',
#  'MDA-056_mask_roi.nii.gz\n',
#  'MDA-057_pt_roi.nii.gz\n',
#  'MDA-057_ct_roi.nii.gz\n',
#  'MDA-057_mask_roi.nii.gz\n',
#  'MDA-058_pt_roi.nii.gz\n',
#  'MDA-058_ct_roi.nii.gz\n',
#  'MDA-058_mask_roi.nii.gz\n',
#  'MDA-059_pt_roi.nii.gz\n',
#  'MDA-059_ct_roi.nii.gz\n',
#  'MDA-059_mask_roi.nii.gz\n',
#  'MDA-060_pt_roi.nii.gz\n',
#  'MDA-060_ct_roi.nii.gz\n',
#  'MDA-060_mask_roi.nii.gz\n',
#  'MDA-061_pt_roi.nii.gz\n',
#  'MDA-061_ct_roi.nii.gz\n',
#  'MDA-061_mask_roi.nii.gz\n',
#  'MDA-062_pt_roi.nii.gz\n',
#  'MDA-062_ct_roi.nii.gz\n',
#  'MDA-062_mask_roi.nii.gz\n',
#  'MDA-063_pt_roi.nii.gz\n',
#  'MDA-063_ct_roi.nii.gz\n',
#  'MDA-063_mask_roi.nii.gz\n',
#  'MDA-064_pt_roi.nii.gz\n',
#  'MDA-064_ct_roi.nii.gz\n',
#  'MDA-064_mask_roi.nii.gz\n',
#  'MDA-065_pt_roi.nii.gz\n',
#  'MDA-065_ct_roi.nii.gz\n',
#  'MDA-065_mask_roi.nii.gz\n',
#  'MDA-066_pt_roi.nii.gz\n',
#  'MDA-066_ct_roi.nii.gz\n',
#  'MDA-066_mask_roi.nii.gz\n',
#  'MDA-067_pt_roi.nii.gz\n',
#  'MDA-067_ct_roi.nii.gz\n',
#  'MDA-067_mask_roi.nii.gz\n',
#  'MDA-068_pt_roi.nii.gz\n',
#  'MDA-068_ct_roi.nii.gz\n',
#  'MDA-068_mask_roi.nii.gz\n',
#  'MDA-069_pt_roi.nii.gz\n',
#  'MDA-069_ct_roi.nii.gz\n',
#  'MDA-069_mask_roi.nii.gz\n',
#  'MDA-070_pt_roi.nii.gz\n',
#  'MDA-070_ct_roi.nii.gz\n',
#  'MDA-070_mask_roi.nii.gz\n',
#  'MDA-071_pt_roi.nii.gz\n',
#  'MDA-071_ct_roi.nii.gz\n',
#  'MDA-071_mask_roi.nii.gz\n',
#  'MDA-072_pt_roi.nii.gz\n',
#  'MDA-072_ct_roi.nii.gz\n',
#  'MDA-072_mask_roi.nii.gz\n',
#  'MDA-073_pt_roi.nii.gz\n',
#  'MDA-073_ct_roi.nii.gz\n',
#  'MDA-073_mask_roi.nii.gz\n',
#  'MDA-074_pt_roi.nii.gz\n',
#  'MDA-074_ct_roi.nii.gz\n',
#  'MDA-074_mask_roi.nii.gz\n',
#  'MDA-075_pt_roi.nii.gz\n',
#  'MDA-075_ct_roi.nii.gz\n',
#  'MDA-075_mask_roi.nii.gz\n',
#  'MDA-076_pt_roi.nii.gz\n',
#  'MDA-076_ct_roi.nii.gz\n',
#  'MDA-076_mask_roi.nii.gz\n',
#  'MDA-077_pt_roi.nii.gz\n',
#  'MDA-077_ct_roi.nii.gz\n',
#  'MDA-077_mask_roi.nii.gz\n',
#  'MDA-078_pt_roi.nii.gz\n',
#  'MDA-078_ct_roi.nii.gz\n',
#  'MDA-078_mask_roi.nii.gz\n',
#  'MDA-079_pt_roi.nii.gz\n',
#  'MDA-079_ct_roi.nii.gz\n',
#  'MDA-079_mask_roi.nii.gz\n',
#  'MDA-080_pt_roi.nii.gz\n',
#  'MDA-080_ct_roi.nii.gz\n',
#  'MDA-080_mask_roi.nii.gz\n',
#  'MDA-081_pt_roi.nii.gz\n',
#  'MDA-081_ct_roi.nii.gz\n',
#  'MDA-081_mask_roi.nii.gz\n',
#  'MDA-082_pt_roi.nii.gz\n',
#  'MDA-082_ct_roi.nii.gz\n',
#  'MDA-082_mask_roi.nii.gz\n',
#  'MDA-083_pt_roi.nii.gz\n',
#  'MDA-083_ct_roi.nii.gz\n',
#  'MDA-083_mask_roi.nii.gz\n',
#  'MDA-084_pt_roi.nii.gz\n',
#  'MDA-084_ct_roi.nii.gz\n',
#  'MDA-084_mask_roi.nii.gz\n',
#  'MDA-085_pt_roi.nii.gz\n',
#  'MDA-085_ct_roi.nii.gz\n',
#  'MDA-085_mask_roi.nii.gz\n',
#  'MDA-086_pt_roi.nii.gz\n',
#  'MDA-086_ct_roi.nii.gz\n',
#  'MDA-086_mask_roi.nii.gz\n',
#  'MDA-087_pt_roi.nii.gz\n',
#  'MDA-087_ct_roi.nii.gz\n',
#  'MDA-087_mask_roi.nii.gz\n',
#  'MDA-088_pt_roi.nii.gz\n',
#  'MDA-088_ct_roi.nii.gz\n',
#  'MDA-088_mask_roi.nii.gz\n',
#  'MDA-089_pt_roi.nii.gz\n',
#  'MDA-089_ct_roi.nii.gz\n',
#  'MDA-089_mask_roi.nii.gz\n',
#  'MDA-090_pt_roi.nii.gz\n',
#  'MDA-090_ct_roi.nii.gz\n',
#  'MDA-090_mask_roi.nii.gz\n',
#  'MDA-091_pt_roi.nii.gz\n',
#  'MDA-091_ct_roi.nii.gz\n',
#  'MDA-091_mask_roi.nii.gz\n',
#  'MDA-092_pt_roi.nii.gz\n',
#  'MDA-092_ct_roi.nii.gz\n',
#  'MDA-092_mask_roi.nii.gz\n',
#  'MDA-093_pt_roi.nii.gz\n',
#  'MDA-093_ct_roi.nii.gz\n',
#  'MDA-093_mask_roi.nii.gz\n',
#  'MDA-094_pt_roi.nii.gz\n',
#  'MDA-094_ct_roi.nii.gz\n',
#  'MDA-094_mask_roi.nii.gz\n',
#  'MDA-095_pt_roi.nii.gz\n',
#  'MDA-095_ct_roi.nii.gz\n',
#  'MDA-095_mask_roi.nii.gz\n',
#  'MDA-096_pt_roi.nii.gz\n',
#  'MDA-096_ct_roi.nii.gz\n',
#  'MDA-096_mask_roi.nii.gz\n',
#  'MDA-097_pt_roi.nii.gz\n',
#  'MDA-097_ct_roi.nii.gz\n',
#  'MDA-097_mask_roi.nii.gz\n',
#  'MDA-098_pt_roi.nii.gz\n',
#  'MDA-098_ct_roi.nii.gz\n',
#  'MDA-098_mask_roi.nii.gz\n',
#  'MDA-099_pt_roi.nii.gz\n',
#  'MDA-099_ct_roi.nii.gz\n',
#  'MDA-099_mask_roi.nii.gz\n',
#  'MDA-100_pt_roi.nii.gz\n',
#  'MDA-100_ct_roi.nii.gz\n',
#  'MDA-100_mask_roi.nii.gz\n',
#  'MDA-101_pt_roi.nii.gz\n',
#  'MDA-101_ct_roi.nii.gz\n',
#  'MDA-101_mask_roi.nii.gz\n',
#  'MDA-102_pt_roi.nii.gz\n',
#  'MDA-102_ct_roi.nii.gz\n',
#  'MDA-102_mask_roi.nii.gz\n',
#  'MDA-103_pt_roi.nii.gz\n',
#  'MDA-103_ct_roi.nii.gz\n',
#  'MDA-103_mask_roi.nii.gz\n',
#  'MDA-104_pt_roi.nii.gz\n',
#  'MDA-104_ct_roi.nii.gz\n',
#  'MDA-104_mask_roi.nii.gz\n',
#  'MDA-105_pt_roi.nii.gz\n',
#  'MDA-105_ct_roi.nii.gz\n',
#  'MDA-105_mask_roi.nii.gz\n',
#  'MDA-106_pt_roi.nii.gz\n',
#  'MDA-106_ct_roi.nii.gz\n',
#  'MDA-106_mask_roi.nii.gz\n',
#  'MDA-107_pt_roi.nii.gz\n',
#  'MDA-107_ct_roi.nii.gz\n',
#  'MDA-107_mask_roi.nii.gz\n',
#  'MDA-108_pt_roi.nii.gz\n',
#  'MDA-108_ct_roi.nii.gz\n',
#  'MDA-108_mask_roi.nii.gz\n',
#  'MDA-109_pt_roi.nii.gz\n',
#  'MDA-109_ct_roi.nii.gz\n',
#  'MDA-109_mask_roi.nii.gz\n',
#  'MDA-110_pt_roi.nii.gz\n',
#  'MDA-110_ct_roi.nii.gz\n',
#  'MDA-110_mask_roi.nii.gz\n',
#  'MDA-111_pt_roi.nii.gz\n',
#  'MDA-111_ct_roi.nii.gz\n',
#  'MDA-111_mask_roi.nii.gz\n',
#  'MDA-112_pt_roi.nii.gz\n',
#  'MDA-112_ct_roi.nii.gz\n',
#  'MDA-112_mask_roi.nii.gz\n',
#  'MDA-113_pt_roi.nii.gz\n',
#  'MDA-113_ct_roi.nii.gz\n',
#  'MDA-113_mask_roi.nii.gz\n',
#  'MDA-114_pt_roi.nii.gz\n',
#  'MDA-114_ct_roi.nii.gz\n',
#  'MDA-114_mask_roi.nii.gz\n',
#  'MDA-115_pt_roi.nii.gz\n',
#  'MDA-115_ct_roi.nii.gz\n',
#  'MDA-115_mask_roi.nii.gz\n',
#  'MDA-116_pt_roi.nii.gz\n',
#  'MDA-116_ct_roi.nii.gz\n',
#  'MDA-116_mask_roi.nii.gz\n',
#  'MDA-117_pt_roi.nii.gz\n',
#  'MDA-117_ct_roi.nii.gz\n',
#  'MDA-117_mask_roi.nii.gz\n',
#  'MDA-118_pt_roi.nii.gz\n',
#  'MDA-118_ct_roi.nii.gz\n',
#  'MDA-118_mask_roi.nii.gz\n',
#  'MDA-119_pt_roi.nii.gz\n',
#  'MDA-119_ct_roi.nii.gz\n',
#  'MDA-119_mask_roi.nii.gz\n',
#  'MDA-120_pt_roi.nii.gz\n',
#  'MDA-120_ct_roi.nii.gz\n',
#  'MDA-120_mask_roi.nii.gz\n',
#  'MDA-121_pt_roi.nii.gz\n',
#  'MDA-121_ct_roi.nii.gz\n',
#  'MDA-121_mask_roi.nii.gz\n',
#  'MDA-122_pt_roi.nii.gz\n',
#  'MDA-122_ct_roi.nii.gz\n',
#  'MDA-122_mask_roi.nii.gz\n',
#  'MDA-123_pt_roi.nii.gz\n',
#  'MDA-123_ct_roi.nii.gz\n',
#  'MDA-123_mask_roi.nii.gz\n',
#  'MDA-124_pt_roi.nii.gz\n',
#  'MDA-124_ct_roi.nii.gz\n',
#  'MDA-124_mask_roi.nii.gz\n',
#  'MDA-125_pt_roi.nii.gz\n',
#  'MDA-125_ct_roi.nii.gz\n',
#  'MDA-125_mask_roi.nii.gz\n',
#  'MDA-126_pt_roi.nii.gz\n',
#  'MDA-126_ct_roi.nii.gz\n',
#  'MDA-126_mask_roi.nii.gz\n',
#  'MDA-127_pt_roi.nii.gz\n',
#  'MDA-127_ct_roi.nii.gz\n',
#  'MDA-127_mask_roi.nii.gz\n',
#  'MDA-128_pt_roi.nii.gz\n',
#  'MDA-128_ct_roi.nii.gz\n',
#  'MDA-128_mask_roi.nii.gz\n',
#  'MDA-129_pt_roi.nii.gz\n',
#  'MDA-129_ct_roi.nii.gz\n',
#  'MDA-129_mask_roi.nii.gz\n',
#  'MDA-130_pt_roi.nii.gz\n',
#  'MDA-130_ct_roi.nii.gz\n',
#  'MDA-130_mask_roi.nii.gz\n',
#  'MDA-131_pt_roi.nii.gz\n',
#  'MDA-131_ct_roi.nii.gz\n',
#  'MDA-131_mask_roi.nii.gz\n',
#  'MDA-132_pt_roi.nii.gz\n',
#  'MDA-132_ct_roi.nii.gz\n',
#  'MDA-132_mask_roi.nii.gz\n',
#  'MDA-133_pt_roi.nii.gz\n',
#  'MDA-133_ct_roi.nii.gz\n',
#  'MDA-133_mask_roi.nii.gz\n',
#  'MDA-134_pt_roi.nii.gz\n',
#  'MDA-134_ct_roi.nii.gz\n',
#  'MDA-134_mask_roi.nii.gz\n',
#  'MDA-135_pt_roi.nii.gz\n',
#  'MDA-135_ct_roi.nii.gz\n',
#  'MDA-135_mask_roi.nii.gz\n',
#  'MDA-136_pt_roi.nii.gz\n',
#  'MDA-136_ct_roi.nii.gz\n',
#  'MDA-136_mask_roi.nii.gz\n',
#  'MDA-137_pt_roi.nii.gz\n',
#  'MDA-137_ct_roi.nii.gz\n',
#  'MDA-137_mask_roi.nii.gz\n',
#  'MDA-138_pt_roi.nii.gz\n',
#  'MDA-138_ct_roi.nii.gz\n',
#  'MDA-138_mask_roi.nii.gz\n',
#  'MDA-139_pt_roi.nii.gz\n',
#  'MDA-139_ct_roi.nii.gz\n',
#  'MDA-139_mask_roi.nii.gz\n',
#  'MDA-140_pt_roi.nii.gz\n',
#  'MDA-140_ct_roi.nii.gz\n',
#  'MDA-140_mask_roi.nii.gz\n',
#  'MDA-141_pt_roi.nii.gz\n',
#  'MDA-141_ct_roi.nii.gz\n',
#  'MDA-141_mask_roi.nii.gz\n',
#  'MDA-142_pt_roi.nii.gz\n',
#  'MDA-142_ct_roi.nii.gz\n',
#  'MDA-142_mask_roi.nii.gz\n',
#  'MDA-143_pt_roi.nii.gz\n',
#  'MDA-143_ct_roi.nii.gz\n',
#  'MDA-143_mask_roi.nii.gz\n',
#  'MDA-144_pt_roi.nii.gz\n',
#  'MDA-144_ct_roi.nii.gz\n',
#  'MDA-144_mask_roi.nii.gz\n',
#  'MDA-145_pt_roi.nii.gz\n',
#  'MDA-145_ct_roi.nii.gz\n',
#  'MDA-145_mask_roi.nii.gz\n',
#  'MDA-146_pt_roi.nii.gz\n',
#  'MDA-146_ct_roi.nii.gz\n',
#  'MDA-146_mask_roi.nii.gz\n',
#  'MDA-147_pt_roi.nii.gz\n',
#  'MDA-147_ct_roi.nii.gz\n',
#  'MDA-147_mask_roi.nii.gz\n',
#  'MDA-148_pt_roi.nii.gz\n',
#  'MDA-148_ct_roi.nii.gz\n',
#  'MDA-148_mask_roi.nii.gz\n',
#  'MDA-149_pt_roi.nii.gz\n',
#  'MDA-149_ct_roi.nii.gz\n',
#  'MDA-149_mask_roi.nii.gz\n',
#  'MDA-150_pt_roi.nii.gz\n',
#  'MDA-150_ct_roi.nii.gz\n',
#  'MDA-150_mask_roi.nii.gz\n',
#  'MDA-151_pt_roi.nii.gz\n',
#  'MDA-151_ct_roi.nii.gz\n',
#  'MDA-151_mask_roi.nii.gz\n',
#  'MDA-152_pt_roi.nii.gz\n',
#  'MDA-152_ct_roi.nii.gz\n',
#  'MDA-152_mask_roi.nii.gz\n',
#  'MDA-153_pt_roi.nii.gz\n',
#  'MDA-153_ct_roi.nii.gz\n',
#  'MDA-153_mask_roi.nii.gz\n',
#  'MDA-154_pt_roi.nii.gz\n',
#  'MDA-154_ct_roi.nii.gz\n',
#  'MDA-154_mask_roi.nii.gz\n',
#  'MDA-155_pt_roi.nii.gz\n',
#  'MDA-155_ct_roi.nii.gz\n',
#  'MDA-155_mask_roi.nii.gz\n',
#  'MDA-156_pt_roi.nii.gz\n',
#  'MDA-156_ct_roi.nii.gz\n',
#  'MDA-156_mask_roi.nii.gz\n',
#  'MDA-157_pt_roi.nii.gz\n',
#  'MDA-157_ct_roi.nii.gz\n',
#  'MDA-157_mask_roi.nii.gz\n',
#  'MDA-158_pt_roi.nii.gz\n',
#  'MDA-158_ct_roi.nii.gz\n',
#  'MDA-158_mask_roi.nii.gz\n',
#  'MDA-159_pt_roi.nii.gz\n',
#  'MDA-159_ct_roi.nii.gz\n',
#  'MDA-159_mask_roi.nii.gz\n',
#  'MDA-160_pt_roi.nii.gz\n',
#  'MDA-160_ct_roi.nii.gz\n',
#  'MDA-160_mask_roi.nii.gz\n',
#  'MDA-161_pt_roi.nii.gz\n',
#  'MDA-161_ct_roi.nii.gz\n',
#  'MDA-161_mask_roi.nii.gz\n',
#  'MDA-162_pt_roi.nii.gz\n',
#  'MDA-162_ct_roi.nii.gz\n',
#  'MDA-162_mask_roi.nii.gz\n',
#  'MDA-163_pt_roi.nii.gz\n',
#  'MDA-163_ct_roi.nii.gz\n',
#  'MDA-163_mask_roi.nii.gz\n',
#  'MDA-164_pt_roi.nii.gz\n',
#  'MDA-164_ct_roi.nii.gz\n',
#  'MDA-164_mask_roi.nii.gz\n',
#  'MDA-165_pt_roi.nii.gz\n',
#  'MDA-165_ct_roi.nii.gz\n',
#  'MDA-165_mask_roi.nii.gz\n',
#  'MDA-166_pt_roi.nii.gz\n',
#  'MDA-166_ct_roi.nii.gz\n',
#  'MDA-166_mask_roi.nii.gz\n',
#  'MDA-167_pt_roi.nii.gz\n',
#  'MDA-167_ct_roi.nii.gz\n',
#  'MDA-167_mask_roi.nii.gz\n',
#  'MDA-168_pt_roi.nii.gz\n',
#  'MDA-168_ct_roi.nii.gz\n',
#  'MDA-168_mask_roi.nii.gz\n',
#  'MDA-169_pt_roi.nii.gz\n',
#  'MDA-169_ct_roi.nii.gz\n',
#  'MDA-169_mask_roi.nii.gz\n',
#  'MDA-170_pt_roi.nii.gz\n',
#  'MDA-170_ct_roi.nii.gz\n',
#  'MDA-170_mask_roi.nii.gz\n',
#  'MDA-171_pt_roi.nii.gz\n',
#  'MDA-171_ct_roi.nii.gz\n',
#  'MDA-171_mask_roi.nii.gz\n',
#  'MDA-172_pt_roi.nii.gz\n',
#  'MDA-172_ct_roi.nii.gz\n',
#  'MDA-172_mask_roi.nii.gz\n',
#  'MDA-173_pt_roi.nii.gz\n',
#  'MDA-173_ct_roi.nii.gz\n',
#  'MDA-173_mask_roi.nii.gz\n',
#  'MDA-174_pt_roi.nii.gz\n',
#  'MDA-174_ct_roi.nii.gz\n',
#  'MDA-174_mask_roi.nii.gz\n',
#  'MDA-175_pt_roi.nii.gz\n',
#  'MDA-175_ct_roi.nii.gz\n',
#  'MDA-175_mask_roi.nii.gz\n',
#  'MDA-176_pt_roi.nii.gz\n',
#  'MDA-176_ct_roi.nii.gz\n',
#  'MDA-176_mask_roi.nii.gz\n',
#  'MDA-177_pt_roi.nii.gz\n',
#  'MDA-177_ct_roi.nii.gz\n',
#  'MDA-177_mask_roi.nii.gz\n',
#  'MDA-178_pt_roi.nii.gz\n',
#  'MDA-178_ct_roi.nii.gz\n',
#  'MDA-178_mask_roi.nii.gz\n',
#  'MDA-179_pt_roi.nii.gz\n',
#  'MDA-179_ct_roi.nii.gz\n',
#  'MDA-179_mask_roi.nii.gz\n',
#  'MDA-180_pt_roi.nii.gz\n',
#  'MDA-180_ct_roi.nii.gz\n',
#  'MDA-180_mask_roi.nii.gz\n',
#  'MDA-181_pt_roi.nii.gz\n',
#  'MDA-181_ct_roi.nii.gz\n',
#  'MDA-181_mask_roi.nii.gz\n',
#  'MDA-182_pt_roi.nii.gz\n',
#  'MDA-182_ct_roi.nii.gz\n',
#  'MDA-182_mask_roi.nii.gz\n',
#  'MDA-183_pt_roi.nii.gz\n',
#  'MDA-183_ct_roi.nii.gz\n',
#  'MDA-183_mask_roi.nii.gz\n',
#  'MDA-184_pt_roi.nii.gz\n',
#  'MDA-184_ct_roi.nii.gz\n',
#  'MDA-184_mask_roi.nii.gz\n',
#  'MDA-185_pt_roi.nii.gz\n',
#  'MDA-185_ct_roi.nii.gz\n',
#  'MDA-185_mask_roi.nii.gz\n',
#  'MDA-186_pt_roi.nii.gz\n',
#  'MDA-186_ct_roi.nii.gz\n',
#  'MDA-186_mask_roi.nii.gz\n',
#  'MDA-187_pt_roi.nii.gz\n',
#  'MDA-187_ct_roi.nii.gz\n',
#  'MDA-187_mask_roi.nii.gz\n',
#  'MDA-188_pt_roi.nii.gz\n',
#  'MDA-188_ct_roi.nii.gz\n',
#  'MDA-188_mask_roi.nii.gz\n',
#  'MDA-189_pt_roi.nii.gz\n',
#  'MDA-189_ct_roi.nii.gz\n',
#  'MDA-189_mask_roi.nii.gz\n',
#  'MDA-190_pt_roi.nii.gz\n',
#  'MDA-190_ct_roi.nii.gz\n',
#  'MDA-190_mask_roi.nii.gz\n',
#  'MDA-191_pt_roi.nii.gz\n',
#  'MDA-191_ct_roi.nii.gz\n',
#  'MDA-191_mask_roi.nii.gz\n',
#  'MDA-192_pt_roi.nii.gz\n',
#  'MDA-192_ct_roi.nii.gz\n',
#  'MDA-192_mask_roi.nii.gz\n',
#  'MDA-193_pt_roi.nii.gz\n',
#  'MDA-193_ct_roi.nii.gz\n',
#  'MDA-193_mask_roi.nii.gz\n',
#  'MDA-194_pt_roi.nii.gz\n',
#  'MDA-194_ct_roi.nii.gz\n',
#  'MDA-194_mask_roi.nii.gz\n',
#  'MDA-195_pt_roi.nii.gz\n',
#  'MDA-195_ct_roi.nii.gz\n',
#  'MDA-195_mask_roi.nii.gz\n',
#  'MDA-196_pt_roi.nii.gz\n',
#  'MDA-196_ct_roi.nii.gz\n',
#  'MDA-196_mask_roi.nii.gz\n',
#  'MDA-197_pt_roi.nii.gz\n',
#  'MDA-197_ct_roi.nii.gz\n',
#  'MDA-197_mask_roi.nii.gz\n',
#  'MDA-198_pt_roi.nii.gz\n',
#  'MDA-198_ct_roi.nii.gz\n',
#  'MDA-198_mask_roi.nii.gz\n',
#  'MDA-199_pt_roi.nii.gz\n',
#  'MDA-199_ct_roi.nii.gz\n',
#  'MDA-199_mask_roi.nii.gz\n',
#  'MDA-200_pt_roi.nii.gz\n',
#  'MDA-200_ct_roi.nii.gz\n',
#  'MDA-200_mask_roi.nii.gz\n',
#  'MDA-201_pt_roi.nii.gz\n',
#  'MDA-201_ct_roi.nii.gz\n',
#  'MDA-201_mask_roi.nii.gz\n']
